# %%
from grid import Pacman_grid
from config import Hyper, Constants

print("\n"*10)
print("-"*100)
print("Start of environment design for Pacman")
Hyper.display()
print("-"*100)
print("The grid is updated and printed for each step. In each cell you see the following symbols:")
print("X - obstacle")
print(". - empty")
print("b - breadcrumb")
print("A - Agent (Pacman)")
print("G - Ghost")
pacman_grid = Pacman_grid()
for i in range(Hyper.total_episodes):
    pacman_grid.reset()
    done = False
    while done == False:
        if Hyper.is_ghost:
            done = pacman_grid.ghost_step(i)
        else:
            done = pacman_grid.step(i)
    episodes = i + 1
    pacman_grid.print_episode_results(episodes)
    pacman_grid.save_episode_stats()

if Hyper.print_images:
    pacman_grid.print_results()
print("The grid is updated and printed for each step. In each cell you see the following symbols:")
print("X - obstacle")
print(". - empty")
print("b - breadcrumb")
print("A - Agent (Pacman)")
print("G - Ghost")
print("\n"*5)  
print("-"*100)
Hyper.display()
print("End of environment design for Pacman")
print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Start of environment design for Pacman
# The Hyperparameters
# -------------------
# total number of breadcrumbs 2
# output images can be found in the images folder
# ----------------------------------------------------------------------------------------------------
# The grid is updated and printed for each step. In each cell you see the following symbols:
# X - obstacle
# . - empty
# b - breadcrumb
# A - Agent (Pacman)
# G - Ghost
#
# Environment for step 1
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X A X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X G X     cells 42 - 48
#
# Environment for step 2
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X A X . X     cells 28 - 34
# X . . . X G X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 3
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X A X . X     cells 28 - 34
# X . . . G . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 4
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X A X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X G X X     cells 42 - 48
#
# Environment for step 5
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . A X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X G X     cells 42 - 48
#
# Environment for step 6
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . A . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X G     cells 42 - 48
#
# Environment for step 7
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . G     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 8
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . G     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 9
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . G     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 10
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . G     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 11
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X G X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 12
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X G X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 13
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . G X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 14
# X X X X X X X     cells 0 - 6
# X X . . X G X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 15
# X X X X X X X     cells 0 - 6
# X X . . G b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 16
# X X X X X X X     cells 0 - 6
# X X . G X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 17
# X X X G X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . A . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 18
# X X G X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . A X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 19
# X X X X X X X     cells 0 - 6
# X X G . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . A X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 20
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . G A . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 21
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . A . X     cells 14 - 20
# X . G . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 22
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . . A X     cells 14 - 20
# X . . G X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 23
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . . A X     cells 14 - 20
# X . G . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 24
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . A . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . G . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 25
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . A . X     cells 14 - 20
# X . G . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 26
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . A . X     cells 14 - 20
# X . . G X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 27
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X A . . X     cells 14 - 20
# X . . . G . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 28
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . A X G X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 29
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . A X . G     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 30
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X A . . X     cells 14 - 20
# X . . . X G X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 31
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . A . X     cells 14 - 20
# X . . . G . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 32
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X . A . X     cells 14 - 20
# X . . G X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 33
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X A . . X     cells 14 - 20
# X . G . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 34
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . G . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 35
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X A . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X G X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 36
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . G . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 37
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . G . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 38
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X G X X X X     cells 42 - 48
#
# Environment for step 39
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 40
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X G . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 41
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 42
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X G . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 43
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# G . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 44
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X G . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 45
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X G X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 46
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# G . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 47
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# G . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 48
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# G . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 49
# X X X X X X X     cells 0 - 6
# X X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# G . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 50
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# G . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 51
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X G X A . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 52
# X X X X X X X     cells 0 - 6
# X X . A X b X     cells 7 - 13
# G . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 53
# X X X X X X X     cells 0 - 6
# G X A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 54
# X X X X X X X     cells 0 - 6
# X G A . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 55
# X X X X X X X     cells 0 - 6
# X X G . X b X     cells 7 - 13
# X . X . . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
# You lost to the ghost!
# Completed environment after 1 episodes and 55 timesteps, total reward: -2618
#
# Environment for step 1
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . A . X . X     cells 21 - 27
# G . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 2
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# G . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 3
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# G X X X X X X     cells 42 - 48
#
# Environment for step 4
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 5
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X G X X X X     cells 42 - 48
#
# Environment for step 6
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . A . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 7
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . A . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# G X X X X X X     cells 42 - 48
#
# Environment for step 8
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . A . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 9
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X G X X X X     cells 42 - 48
#
# Environment for step 10
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X A X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 11
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X A X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X G X X X X     cells 42 - 48
#
# Environment for step 12
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X G X X X X X     cells 42 - 48
#
# Environment for step 13
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# G X X X X X X     cells 42 - 48
#
# Environment for step 14
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# G . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 15
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X A X . X . X     cells 28 - 34
# X G . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 16
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . G . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 17
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X . G . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 18
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X . X b . . X     cells 14 - 20
# X A . . X . X     cells 21 - 27
# X G X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 19
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# G . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 20
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# X A X b . . X     cells 14 - 20
# G . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
#
# Environment for step 21
# X X X X X X X     cells 0 - 6
# X X . . X b X     cells 7 - 13
# A . X b . . X     cells 14 - 20
# X . . . X . X     cells 21 - 27
# X . X . X . X     cells 28 - 34
# X . . . X . X     cells 35 - 41
# X X X X X X X     cells 42 - 48
# You lost to the ghost!
# Completed environment after 2 episodes and 21 timesteps, total reward: -1411
# The grid is updated and printed for each step. In each cell you see the following symbols:
# X - obstacle
# . - empty
# b - breadcrumb
# A - Agent (Pacman)
# G - Ghost
#
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------
# The Hyperparameters
# -------------------
# total number of breadcrumbs 2
# output images can be found in the images folder
# End of environment design for Pacman
# ----------------------------------------------------------------------------------------------------
